# %% [markdown]
# ## Unemployment analysis with python

# %% [markdown]
# Unemployment analysis with python is a dataset consisting of where we have information of number of people of India who were unemployed during covid-19 panademic so we need to calculate the unemployment rate of those people based on the given dataset.

# %% [markdown]
# Link to download the dataset
#
# https://www.kaggle.com/datasets/gokulrajkmv/unemployment-in-india?select=Unemployment+in+India.csv

# %%
# Impotant libraries which we will use in this project:-

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# First we will load our dataset for that we will use read_csv

df = pd.read_csv("Unemployment in India.csv")
# This displays all the cokumns same for rows also if we specify rows
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
from IPython import display
display.Image("C:\\Users\\Malvika\\Downloads\\unemployment.JPG")

# %%
# head() will display the first 5 rows of the dataset

df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
# tail() will display the last 5 rows of the dataset

df.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
# To check the shape of our dataset

df.shape  # it has 768 rows and 7 columns
# Out:
# (768, 7)

# %%
# To check the size of our dataset

df.size  # the total size
# Out:
# 5376

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.describe()  # describe() provides statistical measures such as count, mean, standard deviation, minimum, quartiles, and maximum values for each numeric column in the DataFrame.
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %% [markdown]
# ### We can interpret our data as per above statistical measures as follows:-
#
# - We have data with super high std(standard deviation)
# - The range of 	Estimated Unemployment Rate (%) is from 0.000000 to 76.740000
# - The range of Estimated Employed is from 49420.0 to 45777510.0
# - The range of Estimated Labour Participation Rate (%) is from 13.330000 to 72.570000

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %% [markdown]
# We can see here our column names has not unrequired space in front of the names so we can rename them so that we can use it smoothly for our analysis

# %%
df.columns = ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
       'Estimated Employed', 'Estimated Labour Participation Rate (%)',
       'Area']

# %%
df.isnull()  # this will check the null values in the dataset as here our data showing "False" that means it has no null values
# Out:
#      Region   Date  Frequency  Estimated Unemployment Rate (%)  \
# 0     False  False      False                            False
# 1     False  False      False                            False
# 2     False  False      False                            False
# 3     False  False      False                            False
# 4     False  False      False                            False
# ..      ...    ...        ...                              ...
# 763    True   True       True                             True
# 764    True   True       True                             True
# 765    True   True       True                             True
# 766    True   True       True                             True
# 767    True   True       True                             True
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0                 False                                    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Region                                     28
# Date                                       28
# Frequency                                  28
# Estimated Unemployment Rate (%)            28
# Estimated Employed                         28
# Estimated Labour Participation Rate (%)    28
# Area                                       28
# dtype: int64

# %% [markdown]
# So we per the above observation we can see that we have null values in mainly every column so now we need to treat them correctly

# %%
df["Region"].tail(20)
# Out:
# 748    West Bengal
# 749    West Bengal
# 750    West Bengal
# 751    West Bengal
# 752    West Bengal
# 753    West Bengal
# 754            NaN
# 755            NaN
# 756            NaN
# 757            NaN
# 758            NaN
# 759            NaN
# 760            NaN
# 761            NaN
# 762            NaN
# 763            NaN
# 764            NaN
# 765            NaN
# 766            NaN
# 767            NaN
# Name: Region, dtype: object

# %%
df["Date"].tail(20)
# Out:
# 748     31-01-2020
# 749     29-02-2020
# 750     31-03-2020
# 751     30-04-2020
# 752     31-05-2020
# 753     30-06-2020
# 754            NaN
# 755            NaN
# 756            NaN
# 757            NaN
# 758            NaN
# 759            NaN
# 760            NaN
# 761            NaN
# 762            NaN
# 763            NaN
# 764            NaN
# 765            NaN
# 766            NaN
# 767            NaN
# Name: Date, dtype: object

# %%
df["Frequency"].tail(20)
# Out:
# 748    Monthly
# 749    Monthly
# 750    Monthly
# 751    Monthly
# 752    Monthly
# 753    Monthly
# 754        NaN
# 755        NaN
# 756        NaN
# 757        NaN
# 758        NaN
# 759        NaN
# 760        NaN
# 761        NaN
# 762        NaN
# 763        NaN
# 764        NaN
# 765        NaN
# 766        NaN
# 767        NaN
# Name: Frequency, dtype: object

# %%
df["Estimated Unemployment Rate (%)"].tail(20)
# Out:
# 748     7.27
# 749     7.55
# 750     6.67
# 751    15.63
# 752    15.22
# 753     9.86
# 754      NaN
# 755      NaN
# 756      NaN
# 757      NaN
# 758      NaN
# 759      NaN
# 760      NaN
# 761      NaN
# 762      NaN
# 763      NaN
# 764      NaN
# 765      NaN
# 766      NaN
# 767      NaN
# Name: Estimated Unemployment Rate (%), dtype: float64

# %%
df["Estimated Employed"].tail(20)
# Out:
# 748    11208617.0
# 749    10871168.0
# 750    10806105.0
# 751     9299466.0
# 752     9240903.0
# 753     9088931.0
# 754           NaN
# 755           NaN
# 756           NaN
# 757           NaN
# 758           NaN
# 759           NaN
# 760           NaN
# 761           NaN
# 762           NaN
# 763           NaN
# 764           NaN
# 765           NaN
# 766           NaN
# 767           NaN
# Name: Estimated Employed, dtype: float64

# %%
df["Estimated Labour Participation Rate (%)"].tail(20)
# Out:
# 748    45.39
# 749    44.09
# 750    43.34
# 751    41.20
# 752    40.67
# 753    37.57
# 754      NaN
# 755      NaN
# 756      NaN
# 757      NaN
# 758      NaN
# 759      NaN
# 760      NaN
# 761      NaN
# 762      NaN
# 763      NaN
# 764      NaN
# 765      NaN
# 766      NaN
# 767      NaN
# Name: Estimated Labour Participation Rate (%), dtype: float64

# %%
df["Area"].tail(20)
# Out:
# 748    Urban
# 749    Urban
# 750    Urban
# 751    Urban
# 752    Urban
# 753    Urban
# 754      NaN
# 755      NaN
# 756      NaN
# 757      NaN
# 758      NaN
# 759      NaN
# 760      NaN
# 761      NaN
# 762      NaN
# 763      NaN
# 764      NaN
# 765      NaN
# 766      NaN
# 767      NaN
# Name: Area, dtype: object

# %% [markdown]
# We can see the all the last rows of the dataset consists NaN values as they also did not consists any region so we can simply drop the NaN values

# %%
df=df.dropna(axis=0)

# %%
df.shape
# Out:
# (740, 7)

# %%
df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %% [markdown]
# Now we can see our dataset has no NaN values

# %%
# To check for duplicate values

duplicate_count = df.duplicated().sum()
print(duplicate_count)
# Out:
# 0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df["Region"].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
#  31-10-2019    55
#  30-11-2019    55
#  31-05-2019    54
#  30-06-2019    54
#  31-07-2019    54
#  31-08-2019    53
#  31-12-2019    53
#  31-01-2020    53
#  29-02-2020    53
#  30-09-2019    52
#  31-03-2020    52
#  30-04-2020    51
#  31-05-2020    51
#  30-06-2020    50
# Name: count, dtype: int64

# %%
df['Frequency'].value_counts()
# Out:
# Frequency
# Monthly     381
#  Monthly    359
# Name: count, dtype: int64

# %%
# As we can see some of the Monthly names have unrequired space so to correct it:-

df["Frequency"] = df["Frequency"].str.replace(" Monthly", "Monthly")
# Out:
# C:\Users\Malvika\AppData\Local\Temp\ipykernel_6212\1402547857.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Frequency"] = df["Frequency"].str.replace(" Monthly", "Monthly")

# %%
df['Frequency'].value_counts()
# Out:
# Frequency
# Monthly    740
# Name: count, dtype: int64

# %%
df['Estimated Unemployment Rate (%)'].value_counts()
# Out:
# Estimated Unemployment Rate (%)
# 0.00     11
# 3.31      4
# 12.50     3
# 5.45      3
# 6.67      3
#          ..
# 13.70     1
# 4.03      1
# 40.59     1
# 3.69      1
# 9.86      1
# Name: count, Length: 624, dtype: int64

# %%
df['Estimated Employed'].value_counts()
# Out:
# Estimated Employed
# 11999139.0    1
# 1183770.0     1
# 241366.0      1
# 246596.0      1
# 227804.0      1
#              ..
# 6021921.0     1
# 6395022.0     1
# 6164215.0     1
# 6189471.0     1
# 9088931.0     1
# Name: count, Length: 740, dtype: int64

# %%
df['Estimated Labour Participation Rate (%)'].value_counts()
# Out:
# Estimated Labour Participation Rate (%)
# 40.43    3
# 42.82    3
# 39.92    3
# 43.25    3
# 39.04    3
#         ..
# 44.08    1
# 46.50    1
# 45.79    1
# 44.79    1
# 40.67    1
# Name: count, Length: 626, dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Area
# Urban    381
# Rural    359
# Name: count, dtype: int64

# %%
df.head()
# Out:
#            Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural

# %% [markdown]
# ## Employement vs Unemployement

# %%
from sklearn.preprocessing import normalize

employed = df['Estimated Employed'].iloc[:50]
employed.head(2)
# Out:
# 0    11999139.0
# 1    11755881.0
# Name: Estimated Employed, dtype: float64

# %%
unemployed = df['Estimated Unemployment Rate (%)'].iloc[:50]
unemployed.head(2)
# Out:
# 0    3.65
# 1    3.05
# Name: Estimated Unemployment Rate (%), dtype: float64

# %%
e = normalize([employed])
print(e)
u = normalize([unemployed])
print(u)
# Out:
# [[0.1176713  0.11528576 0.11853005 0.12048144 0.12019772 0.1178505
#   0.11177302 0.12286153 0.11784328 0.11496936 0.11140016 0.08622814
#   0.09342695 0.15271865 0.11522155 0.08750688 0.0971989  0.09112373
#   0.11246603 0.08233567 0.09439251 0.11200166 0.08299182 0.09687732
#   0.09734249 0.07399052 0.23852047 0.23631772 0.22799348 0.21829792
#   0.23443473 0.23588062 0.22011986 0.22471467 0.22956383 0.22720225
#   0.22229589 0.14362102 0.1377865  0.2022382  0.06137998 0.06480845
#   0.06623038 0.06479931 0.06365274 0.06907644 0.06808686 0.06442363
#   0.06115621 0.0671478 ]]
# [[0.04200038 0.03509621 0.04315107 0.03820308 0.05949094 0.04050447
#   0.04740864 0.05040045 0.05569365 0.06800609 0.04671823 0.18744826
#   0.16639053 0.00978091 0.04936483 0.05845532 0.04901962 0.06662526
#   0.05132101 0.05350733 0.0536224  0.04936483 0.03751267 0.04338121
#   0.10793522 0.         0.10666945 0.11737092 0.15465344 0.12657648
# ...

# %%
e =e.flatten()
print(e)

plt.plot(e)
plt.show()


u = u.flatten()
print(u)

plt.plot(u)
plt.show()
# Out:
# [0.1176713  0.11528576 0.11853005 0.12048144 0.12019772 0.1178505
#  0.11177302 0.12286153 0.11784328 0.11496936 0.11140016 0.08622814
#  0.09342695 0.15271865 0.11522155 0.08750688 0.0971989  0.09112373
#  0.11246603 0.08233567 0.09439251 0.11200166 0.08299182 0.09687732
#  0.09734249 0.07399052 0.23852047 0.23631772 0.22799348 0.21829792
#  0.23443473 0.23588062 0.22011986 0.22471467 0.22956383 0.22720225
#  0.22229589 0.14362102 0.1377865  0.2022382  0.06137998 0.06480845
#  0.06623038 0.06479931 0.06365274 0.06907644 0.06808686 0.06442363
#  0.06115621 0.0671478 ]
# [0.04200038 0.03509621 0.04315107 0.03820308 0.05949094 0.04050447
#  0.04740864 0.05040045 0.05569365 0.06800609 0.04671823 0.18744826
#  0.16639053 0.00978091 0.04936483 0.05845532 0.04901962 0.06662526
#  0.05132101 0.05350733 0.0536224  0.04936483 0.03751267 0.04338121
#  0.10793522 0.         0.10666945 0.11737092 0.15465344 0.12657648
#  0.10206667 0.1434917  0.14268621 0.11691064 0.10505848 0.11058181
# ...

# %%
plt.plot(e, color='red')
plt.plot(u, color='blue')
plt.xlabel("Employed")
plt.ylabel("Unemployed")
plt.show()

# %%
df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %%
# To print the month of unemployment

import datetime as dt
import calendar
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df['month_int'] =  df['Date'].dt.month
df['month'] =  df['month_int'].apply(lambda x: calendar.month_abbr[x])
# Out:
# C:\Users\Malvika\AppData\Local\Temp\ipykernel_6212\2661298039.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
# C:\Users\Malvika\AppData\Local\Temp\ipykernel_6212\2661298039.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_int'] =  df['Date'].dt.month
# C:\Users\Malvika\AppData\Local\Temp\ipykernel_6212\2661298039.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#              Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 749     West Bengal 2020-02-29   Monthly                             7.55
# 750     West Bengal 2020-03-31   Monthly                             6.67
# 751     West Bengal 2020-04-30   Monthly                            15.63
# 752     West Bengal 2020-05-31   Monthly                            15.22
# 753     West Bengal 2020-06-30   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# ...

# %%
df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# month_int                                  0
# month                                      0
# dtype: int64

# %%
df.head()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#    month_int month
# 0          5   May
# 1          6   Jun
# 2          7   Jul
# 3          8   Aug
# ...

# %%
# Now we can drop the unwanted columns which are:-

df = df.drop(columns=["Frequency", "month_int"])

# %%
df
# Out:
#              Region       Date  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31                             3.65
# 1    Andhra Pradesh 2019-06-30                             3.05
# 2    Andhra Pradesh 2019-07-31                             3.75
# 3    Andhra Pradesh 2019-08-31                             3.32
# 4    Andhra Pradesh 2019-09-30                             5.17
# ..              ...        ...                              ...
# 749     West Bengal 2020-02-29                             7.55
# 750     West Bengal 2020-03-31                             6.67
# 751     West Bengal 2020-04-30                            15.63
# 752     West Bengal 2020-05-31                            15.22
# 753     West Bengal 2020-06-30                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area month
# 0            11999139.0                                    43.24  Rural   May
# ...

# %%
# Now we can see 10 stated with the highest employment 


df1 = df[["Region", "Estimated Unemployment Rate (%)"]].groupby("Region").sum().sort_values(by="Estimated Unemployment Rate (%)", ascending=False)

# %%
df1.head(10)
# Out:
#                   Estimated Unemployment Rate (%)
# Region
# Tripura                                    793.81
# Haryana                                    735.93
# Jharkhand                                  576.38
# Bihar                                      529.71
# Himachal Pradesh                           519.13
# Delhi                                      461.87
# Rajasthan                                  393.63
# Uttar Pradesh                              351.44
# Jammu & Kashmir                            339.96
# Punjab                                     336.87

# %%
# group by region and area

group = df.groupby(["Region", "Area"]).agg({'Estimated Unemployment Rate (%)': 'mean'})

# %%
group
# Out:
#                         Estimated Unemployment Rate (%)
# Region           Area
# Andhra Pradesh   Rural                         5.526429
#                  Urban                         9.427857
# Assam            Rural                         4.490833
#                  Urban                         8.088571
# Bihar            Rural                        16.770000
#                  Urban                        21.066429
# Chandigarh       Urban                        15.991667
# Chhattisgarh     Rural                         6.628571
#                  Urban                        11.852143
# Delhi            Rural                        15.258571
#                  Urban                        17.732143
# Goa              Rural                         8.390000
#                  Urban                        10.158333
# Gujarat          Rural                         5.917143
#                  Urban                         7.410714
# ...

# %%
# months with highest unemployment

df3 = df[["month","Estimated Unemployment Rate (%)"]].groupby("month").sum().sort_values(by="Estimated Unemployment Rate (%)", ascending  =False)
df3.head(10)
# Out:
#        Estimated Unemployment Rate (%)
# month
# May                            1747.85
# Apr                            1205.72
# Jun                            1097.56
# Mar                             556.43
# Oct                             544.55
# Nov                             542.76
# Feb                             528.13
# Jan                             527.39
# Aug                             510.81
# Dec                             503.36

# %%
df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# month                                      0
# dtype: int64

# %% [markdown]
# ## Data Visulaization

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %%
y=df['Estimated Unemployment Rate (%)']
x=df['Region']
pr= plt.figure(figsize=(40, 15))
plt.xlabel("States",fontweight='bold',fontsize=30)
plt.ylabel("Estimated Unemployment rate",fontweight='bold',fontsize=30)
plt.xticks(fontweight='bold',rotation='vertical',fontsize=30)
plt.bar(x,y, color="blue",align='center')
# Out:
# <BarContainer object of 740 artists>

# %%
y=df['Estimated Unemployment Rate (%)']
x=df['month']
pr= plt.figure(figsize=(40, 15))
plt.xlabel("Months",fontweight='bold',fontsize=30)
plt.ylabel("Estimated Unemployment rate",fontweight='bold',fontsize=30)
plt.xticks(fontweight='bold',rotation='vertical',fontsize=30)
plt.bar(x,y, color="lightgreen",align='center')
# Out:
# <BarContainer object of 740 artists>

# %%
y=df['Estimated Unemployment Rate (%)']
x=df['Area']
pr= plt.figure(figsize=(40, 15))
plt.xlabel("States",fontweight='bold',fontsize=30)
plt.ylabel("Estimated Unemployment rate",fontweight='bold',fontsize=30)
plt.xticks(fontweight='bold',rotation='vertical',fontsize=30)
plt.bar(x,y, color="yellow",align='center')
# Out:
# <BarContainer object of 740 artists>

# %%
sns.scatterplot(y="Estimated Unemployment Rate (%)", x="Area", hue="Region", data=df)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Estimated Unemployment Rate (%)'>

# %%
state = df.groupby(["Region"])[["Estimated Unemployment Rate (%)", "Estimated Employed", "Estimated Labour Participation Rate (%)"]].mean()
state = pd.DataFrame(state).reset_index()

# %%
state
# Out:
#               Region  Estimated Unemployment Rate (%)  Estimated Employed  \
# 0     Andhra Pradesh                         7.477143        8.154093e+06
# 1              Assam                         6.428077        5.354772e+06
# 2              Bihar                        18.918214        1.236619e+07
# 3         Chandigarh                        15.991667        3.168312e+05
# 4       Chhattisgarh                         9.240357        4.303499e+06
# 5              Delhi                        16.495357        2.627513e+06
# 6                Goa                         9.274167        2.263083e+05
# 7            Gujarat                         6.663929        1.140201e+07
# 8            Haryana                        26.283214        3.557072e+06
# 9   Himachal Pradesh                        18.540357        1.059824e+06
# 10   Jammu & Kashmir                        16.188571        1.799932e+06
# 11         Jharkhand                        20.585000        4.469240e+06
# ...

# %%
# Box plot


fig = px.box(state, x='Region', y='Estimated Unemployment Rate (%)', title='Unemployment Rate by Region',
             points="all", color='Region')

# Update the layout to set the order of the 'Region' categories on the x-axis
fig.update_layout(xaxis={'categoryorder': 'total descending'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="4f9a4ab2-4879-4f9f-8b39-958812c97274" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f9a4ab2-4879-4f9f-8b39-958812c97274")) {                    Plotly.newPlot(                        "4f9a4ab2-4879-4f9f-8b39-958812c97274",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Region=%{x}<br>Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh"],"x0":" ","xaxis":"x","y":[7.477142857142857],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Region=%{
# ...

# %%
fig = px.scatter_geo(ds,'longitude', 'latitude', color="state",
                     hover_name="state", size="estimated unemployment rate",
                     animation_frame="month",scope='asia',title='Impack of lockdown on employement in India')

fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 2000

fig.update_geos(lataxis_range=[5,40], lonaxis_range=[65, 100],oceancolor="lightblue",
    showocean=True)

fig.show()
# Out:
# <div>                            <div id="0e53aabc-45a9-4f96-9c3a-9ec07f66c8e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e53aabc-45a9-4f96-9c3a-9ec07f66c8e4")) {                    Plotly.newPlot(                        "0e53aabc-45a9-4f96-9c3a-9ec07f66c8e4",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[7.477142857142857],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Estimated Unemploym
# ...

# %%
print("State with highest Unemployment:-",df['Region'].value_counts().idxmax())
# Out:
# State with highest Unemployment:- Andhra Pradesh

# %%
print("State with highest Unemployment:-",df['Region'].value_counts().idxmin())
# Out:
# State with highest Unemployment:- Chandigarh

# %%
print("Month with highest Unemployment:-",df['month'].value_counts().idxmax())
# Out:
# Month with highest Unemployment:- May

# %%
print("Month with highest Unemployment:-",df['month'].value_counts().idxmin())
# Out:
# Month with highest Unemployment:- Apr

# %% [markdown]
# ## CONCLUSION
#
# - State with highest Unemployment:- Andhra Pradesh
# - State with Lowest Unemployment:- Chandigarh
# - Month with highest Unemployment:- May
# - Month with lowest Unemployment:- April
# - Graph Progress: Higher The labour participation Lower the unemployment rate
